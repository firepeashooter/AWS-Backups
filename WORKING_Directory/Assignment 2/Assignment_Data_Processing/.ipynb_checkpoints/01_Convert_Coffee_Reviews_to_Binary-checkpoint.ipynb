# %% [markdown]
# # Convert Coffee Reviews to Binary Sentiment
#
# **Input:** `coffee_maker.csv` (5,000 reviews with 1-5 star ratings)
#
# **Output:** `coffee_maker_binary.csv` (reviews with positive/negative sentiment)
#
# This notebook converts the original 5-star rating scale into a binary sentiment label:
# - **positive** = ratings 4 and 5
# - **negative** = ratings 1 and 2
# - Rating 3 (neutral) is dropped because it is too ambiguous to classify as either sentiment.
#
# **Run this notebook first**, before the Data Preparation notebook.

# %%
import pandas as pd

df = pd.read_csv("Restaurant_Reviews.csv")
original_count = len(df)

#Convert rating column to numbers
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')


# Map ratings to binary sentiment (lowercase for consistency across the pipeline).
sentiment_map = {1.0: "negative", 2.0: "negative", 4.0: "positive", 5.0: "positive"}
df = df[df["Rating"].isin(sentiment_map.keys())].copy()
df["sentiment"] = df["Rating"].map(sentiment_map)

# Drop the original rating column, keep sentiment as the new label.
df = df.drop(columns=["Rating"])

# Show results.
print(f"Rows dropped (3-star neutral): {original_count - len(df)}")
print(f"Final dataset: {len(df)} rows\n")
print("Class distribution:")
for label, count in df["sentiment"].value_counts().items():
    pct = count / len(df) * 100
    bar = "*" * int(pct / 2)
    print(f"  {label}: {count:,} ({pct:.1f}%) {bar}")

# Save to new file.
output_file = "Resteraunt_Reviews_Binary.csv"
df.to_csv(output_file, index=False)
print(f"\nSaved to: {output_file}")
# Out:
# Rows dropped (3-star neutral): 1376
# Final dataset: 8624 rows
#
# Class distribution:
#   positive: 6,205 (72.0%) ***********************************
#   negative: 2,419 (28.0%) **************
#
# Saved to: Resteraunt_Reviews_Binary.csv
