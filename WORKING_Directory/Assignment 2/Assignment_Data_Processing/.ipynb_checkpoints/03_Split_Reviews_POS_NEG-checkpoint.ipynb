# %%
# ============================================================
# SPLIT CLEANED REVIEWS INTO POSITIVE AND NEGATIVE FILES
# ============================================================
# Input:  coffee_maker_binary_cleaned.csv (from Data Preparation)
# Output: coffee_maker_binary_cleaned POS.csv (positive only)
#         coffee_maker_binary_cleaned NEG.csv (negative only)
# ============================================================
# These output files are used by the LDA Topic Modeling POS
# and LDA Topic Modeling NEG notebooks in the NLP directory.
# ============================================================

import pandas as pd

df = pd.read_csv("Resteraunt_Reviews_Binary_cleaned.csv")
print(f"Loaded: {len(df)} rows")
print(f"Columns: {list(df.columns)}\n")

# Split by sentiment
pos_df = df[df["sentiment"] == "positive"].copy()
neg_df = df[df["sentiment"] == "negative"].copy()

print(f"Positive reviews: {len(pos_df):,}")
print(f"Negative reviews: {len(neg_df):,}")

# Save to separate files
pos_file = "Resteraunt_Reviews_cleaned POS.csv"
neg_file = "Resteraunt_Reviews_cleaned NEG.csv"

pos_df.to_csv(pos_file, index=False)
neg_df.to_csv(neg_file, index=False)

print(f"\nSaved: {pos_file}")
print(f"Saved: {neg_file}")
print(f"\nCopy these files to the NLP directory for the LDA notebooks.")
# Out:
# Loaded: 7117 rows
# Columns: ['Restaurant', 'Reviewer', 'Review', 'Metadata', 'Time', 'Pictures', '7514', 'sentiment', 'cleaned_text']
#
# Positive reviews: 5,015
# Negative reviews: 2,102
#
# Saved: Resteraunt_Reviews_cleaned POS.csv
# Saved: Resteraunt_Reviews_cleaned NEG.csv
#
# Copy these files to the NLP directory for the LDA notebooks.

# %% [markdown]
# # Split Cleaned Reviews into Positive and Negative Files
#
# **Input:** `coffee_maker_binary_cleaned.csv` (from the Data Preparation notebook)
#
# **Output:**
# - `coffee_maker_binary_cleaned POS.csv` (positive reviews only)
# - `coffee_maker_binary_cleaned NEG.csv` (negative reviews only)
#
# These output files are used by the **LDA Topic Modeling POS** and **LDA Topic Modeling NEG** notebooks in the NLP directory. By splitting the reviews by sentiment before topic modeling, we can discover what themes appear specifically in positive vs. negative feedback.
#
# **Run this notebook after** the Data Preparation notebook has produced `coffee_maker_binary_cleaned.csv`.
